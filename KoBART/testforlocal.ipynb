# %% [markdown]
# Train 데이터 8000개 보고서 연설문

# %%
# make index list
import os
import numpy as np
import json
import pandas as pd
from collections import Counter

json_data=[]
psg_tsv = [] # 원본
psg_tsv_str=[]
smy_tsv = [] # 요약
smy_tsv_str=[]

def listToString(str_list):
    result = ""
    for s in str_list:
        result += s + " "
    return result.strip()

with open('./dacondata/test.json') as f:
    for line in f:
        json_data.append(json.loads(line)) # 전체데이터
        #psg_tsv.append(json_data[i]['article_original']) # 데이터 원문입니다.
        #psg_tsv_str.append(listToString(psg_tsv[i])) #데이터 원문 string으로 출력

        #smy_tsv.append(json_data[i]['abstractive'])
        #smy_tsv_str.append(listToString(smy_tsv[i]))
        
    #print(json_data[5]) # {'id': '365247698', 'abstractive': ['이해찬 대표가 조국 사태와 관련 송구한 입장 표명이 과감한 인적 쇄신으로 이어져야 한다.'],.....

    for i in json_data:
        psg_tsv.append(json_data[i]['article_original'])

    #print(len(json_data))
    #print(json_data[0].keys())
    #print("원문데이터:" , json_data[0]['article_original'])
    #print("요약데이터:" , json_data[0]['abstractive'])

    #print("원문데이터:" , json_data[1]['article_original'])
    #print("요약데이터:" , json_data[1]['abstractive'])

    #print('원문:',psg_tsv[0]) #원문 출력
    #print('요약:',smy_tsv[0]) 

    #print('원문:',psg_tsv[3]) #원문 출력
    #print('요약:',smy_tsv[:1]) 

    #print('원문 전처리데이터:',psg_tsv_str[2]) #원문 출력
    #print('원문 요약데이터:',smy_tsv_str[2])

    #print('원문 전처리데이터:',psg_tsv_str[3]) #원문 출력
    #print('원문 요약데이터:',smy_tsv_str[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5236\965150150.py in <module>
#      30
#      31     for i in json_data:
# ---> 32         psg_tsv.append(json_data[i]['article_original'])
#      33
#      34     #print(len(json_data))
#
# TypeError: list indices must be integers or slices, not dict

# %%
test_labeling = pd.concat([pd.DataFrame(psg_tsv_str),pd.DataFrame(smy_tsv_str)], axis = 1)
test_labeling.columns = ['passage' ,'summary'] # 뉴스 학습데이터 양식 맞추기 (원문  요약문 => 탭 구분)
test_labeling
# Out:
#                                                 passage  \
# 0     더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 1     더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 2     더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 3     더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 4     더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# ...                                                 ...
# 1995  더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 1996  더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 1997  더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 1998  더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
# 1999  더불어민주당 이해찬 대표가 30 일 오후 국회에서 기자간담회를 열고 조국 전 법무부...
#
#                                                 summary
# 0     이해찬 대표가 조국 사태와 관련 송구한 입장 표명이 과감한 인적 쇄신으로 이어져야 한다.
# 1     이해찬 대표가 조국 사태와 관련 송구한 입장 표명이 과감한 인적 쇄신으로 이어져야 한다.
# 2     이해찬 대표가 조국 사태와 관련 송구한 입장 표명이 과감한 인적 쇄신으로 이어져야 한다.
# 3     이해찬 대표가 조국 사태와 관련 송구한 입장 표명이 과감한 인적 쇄신으로 이어져야 한다.
# ...
